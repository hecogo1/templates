# %%
# packages
import pymysql
import pandas as pd

# files
from auth import host, user, password, database
from queries import query_all

# %%
# creating connection
db_connection = pymysql.connect(host = host,
                                        user = user,
                                        password = password,
                                        database = database)

# creating cursor
cursor = db_connection.cursor()

# %%
# getting the query to a dataframe
df = pd.read_sql(query_all, 
                db_connection,
                index_col = 'id')
# Out:
# /Users/hectorcozar/Documents/GitHub/templates/venv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df.head()
# Out:
#          model               cpu_model             os release_date  \
# id
# 1       iPhone        Samsung ARM 1176  iPhone OS 1.0      29-6-07
# 2       iPhone        Samsung ARM 1176  iPhone OS 1.0       5-2-08
# 3    iPhone 3G   Samsung ARM 1176JZF-S  iPhone OS 2.0      7-11-08
# 4   iPhone 3GS  Samsung ARM APL0298C05  iPhone OS 3.0      17-6-09
# 5     iPhone 4                Apple A4        IOS 4.0      21-6-10
#
#    memory_base_model price_base_model memory_upgrade_1 prince_upgrade_1  \
# id
# 1                4GB             499$              8GB             599$
# 2                 NA               NA               NA               NA
# 3                8GB             599$             16GB             699$
# 4                8GB             599$             16GB             649$
# 5                 NA               NA             16GB             599$
#
#    memory_upgrade_2 price_upgrade_2 memory_upgrade_3 price_upgrade_3 inches  \
# id
# ...

# %%
# closing connections
cursor.close()
db_connection.close()
